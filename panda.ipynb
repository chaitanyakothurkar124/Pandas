# %%
import pandas as pd

# %%
s = pd.Series([10, 20, 30, 40])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
type(s)
# Out:
# pandas.Series

# %%
df = pd.DataFrame({
    "name": ["Amit", "Rahul", "Priya"],
    "age": [25, 30, 28],
    "salary": [50000, 70000, 65000]
})

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['name', 'age', 'salary'], dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.head()
# Out:
#     name  age  salary
# 0   Amit   25   50000
# 1  Rahul   30   70000
# 2  Priya   28   65000

# %%
df.head(1)
# Out:
#    name  age  salary
# 0  Amit   25   50000

# %%
df.tail()
# Out:
#     name  age  salary
# 0   Amit   25   50000
# 1  Rahul   30   70000
# 2  Priya   28   65000

# %%
df.tail(1)
# Out:
#     name  age  salary
# 2  Priya   28   65000

# %%
df.sample()
# Out:
#    name  age  salary
# 0  Amit   25   50000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      str
#  1   age     3 non-null      int64
#  2   salary  3 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 218.0 bytes

# %%
df.describe()
# Out:
#              age        salary
# count   3.000000      3.000000
# mean   27.666667  61666.666667
# std     2.516611  10408.329997
# min    25.000000  50000.000000
# 25%    26.500000  57500.000000
# 50%    28.000000  65000.000000
# 75%    29.000000  67500.000000
# max    30.000000  70000.000000

# %%
data = {
    "name": ["Amit", "Rahul", "Priya", "Neha"],
    "age": [25, 30, 28, 35],
    "salary": [50000, 70000, 65000, 90000],
    "department": ["IT", "Finance", "IT", "HR"]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#     name  age  salary department
# 0   Amit   25   50000         IT
# 1  Rahul   30   70000    Finance
# 2  Priya   28   65000         IT
# 3   Neha   35   90000         HR

# %%
df.shape
# Out:
# (4, 4)

# %%
df.columns
# Out:
# Index(['name', 'age', 'salary', 'department'], dtype='str')

# %%
df.dtypes
# Out:
# name            str
# age           int64
# salary        int64
# department      str
# dtype: object

# %%
df.head(2)
# Out:
#     name  age  salary department
# 0   Amit   25   50000         IT
# 1  Rahul   30   70000    Finance

# %%
df.tail(2)
# Out:
#     name  age  salary department
# 2  Priya   28   65000         IT
# 3   Neha   35   90000         HR

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        4 non-null      str
#  1   age         4 non-null      int64
#  2   salary      4 non-null      int64
#  3   department  4 non-null      str
# dtypes: int64(2), str(2)
# memory usage: 291.0 bytes

# %%
df.describe()
# Out:
#              age        salary
# count   4.000000      4.000000
# mean   29.500000  68750.000000
# std     4.203173  16520.189668
# min    25.000000  50000.000000
# 25%    27.250000  61250.000000
# 50%    29.000000  67500.000000
# 75%    31.250000  75000.000000
# max    35.000000  90000.000000

# %%
df[["name"]]
# Out:
#     name
# 0   Amit
# 1  Rahul
# 2  Priya
# 3   Neha

# %%
data = {
    "Amit": 21,
    "Rahul": 25,
    "Priya": 30
}

ages = pd.Series(data)

# %%
ages
# Out:
# Amit     21
# Rahul    25
# Priya    30
# dtype: int64

# %%
ages * 2
# Out:
# Amit     42
# Rahul    50
# Priya    60
# dtype: int64

# %%
ages // 3
# Out:
# Amit      7
# Rahul     8
# Priya    10
# dtype: int64

# %%
ages.mean
# Out:
# <bound method Series.mean of Amit     21
# Rahul    25
# Priya    30
# dtype: int64>

# %%
ages.sum
# Out:
# <bound method Series.sum of Amit     21
# Rahul    25
# Priya    30
# dtype: int64>

# %%
ages.median
# Out:
# <bound method Series.median of Amit     21
# Rahul    25
# Priya    30
# dtype: int64>

# %%
data = {
    "name": ["Amit", "Rahul", "Priya"],
    "age": [25, 30, 28],
    "salary": [50000, 70000, 65000]
}

df = pd.DataFrame(data)

# %%
df["age"] + 2
# Out:
# 0    27
# 1    32
# 2    30
# Name: age, dtype: int64

# %%
df
# Out:
#     name  age  salary
# 0   Amit   25   50000
# 1  Rahul   30   70000
# 2  Priya   28   65000

# %%
df
# Out:
#     name  age  salary  Bonus  Total_salary  (2, Bonus)
# 0   Amit   25   50000   1000         51000        1000
# 1  Rahul   30   70000   1200         71200        1200
# 2  Priya   28   65000    900         65900         900

# %%
df["Total_salary"] = df["salary"] + df["Bonus"]

# %%
df
# Out:
#     name  age  salary  Bonus  Total_salary
# 0   Amit   25   50000   1000         51000
# 1  Rahul   30   70000   1200         71200
# 2  Priya   28   65000    900         65900

# %%
df.drop("Bonus" , axis = 1 )
# Out:
#     name  age  salary  Total_salary  (2, Bonus)
# 0   Amit   25   50000         51000        1000
# 1  Rahul   30   70000         71200        1200
# 2  Priya   28   65000         65900         900

# %%
df.drop((2 ,"Bonus") , axis = 1 )
# Out:
#     name  age  salary  Bonus  Total_salary
# 0   Amit   25   50000   1000         51000
# 1  Rahul   30   70000   1200         71200
# 2  Priya   28   65000    900         65900

# %%
df
# Out:
#     name  age  salary  Bonus  Total_salary  (2, Bonus)
# 0   Amit   25   50000   1000         51000        1000
# 1  Rahul   30   70000   1200         71200        1200
# 2  Priya   28   65000    900         65900         900

# %%
df.drop((2,"Bonus"), axis=1, inplace=True)

# %%
df
# Out:
#     name  age  salary  Bonus  Total_salary
# 0   Amit   25   50000   1000         51000
# 1  Rahul   30   70000   1200         71200
# 2  Priya   28   65000    900         65900

# %%
scores = pd.Series(
    [85, 92, 78, 96],
    index=["Amit", "Rahul", "Priya", "Neha"]
)

# %%
scores
# Out:
# Amit     85
# Rahul    92
# Priya    78
# Neha     96
# dtype: int64

# %%
sc = scores

# %%
sc
# Out:
# Amit     85
# Rahul    92
# Priya    78
# Neha     96
# dtype: int64

# %%
sc.mean()
# Out:
# np.float64(87.75)

# %%
sc.median()
# Out:
# np.float64(88.5)

# %%
sc.max()
# Out:
# np.int64(96)

# %%
sc.min()
# Out:
# np.int64(78)

# %%
data = {
    "name": ["A", "B", "C", "D"],
    "math": [80, 90, 70, 95],
    "science": [85, 88, 75, 92]
}
gf = pd.DataFrame(data)

# %%
gf
# Out:
#   name  math  science
# 0    A    80       85
# 1    B    90       88
# 2    C    70       75
# 3    D    95       92

# %%
gf["total"] = gf["math"] + gf["science"]

# %%
gf
# Out:
#   name  math  science  total
# 0    A    80       85    165
# 1    B    90       88    178
# 2    C    70       75    145
# 3    D    95       92    187

# %%
gf["average"] = gf["total"] // 2

# %%
gf
# Out:
#   name  math  science  total  average
# 0    A    80       85    165       82
# 1    B    90       88    178       89
# 2    C    70       75    145       72
# 3    D    95       92    187       93

# %%
gf["total"].max
# Out:
# <bound method Series.max of 0    A
# 1    B
# 2    C
# 3    D
# Name: name, dtype: str>

# %%
s1 = pd.Series([10, 20, 30], index=["A", "B", "C"])
s2 = pd.Series([5, 10, 15], index=["B", "C", "D"])

print(s1 + s2)
# Out:
# A     NaN
# B    25.0
# C    40.0
# D     NaN
# dtype: float64
