# %%
import pandas as pd

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["Amit", "Rahul", "Priya", "Neha", "Vikram"],
    "age": [25, 32, 28, 35, 24],
    "city": ["Mumbai", "Pune", "Mumbai", "Delhi", "Pune"],
    "salary": [50000, 75000, 65000, 90000, 45000]
})

print(df)
# Out:
#      name  age    city  salary
# 0    Amit   25  Mumbai   50000
# 1   Rahul   32    Pune   75000
# 2   Priya   28  Mumbai   65000
# 3    Neha   35   Delhi   90000
# 4  Vikram   24    Pune   45000

# %%
df[["name"]]
# Out:
#      name
# 0    Amit
# 1   Rahul
# 2   Priya
# 3    Neha
# 4  Vikram

# %%
df[df["age"] > 30]
# Out:
#     name  age   city  salary
# 1  Rahul   32   Pune   75000
# 3   Neha   35  Delhi   90000

# %%
df["age"] > 30
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: age, dtype: bool

# %%
df[(df["age"] > 25) & (df["salary"] > 60000)]
# Out:
#     name  age    city  salary
# 1  Rahul   32    Pune   75000
# 2  Priya   28  Mumbai   65000
# 3   Neha   35   Delhi   90000

# %%
df[["name"]]
# Out:
#      name
# 0    Amit
# 1   Rahul
# 2   Priya
# 3    Neha
# 4  Vikram

# %%
df[["name","salary"]]
# Out:
#      name  salary
# 0    Amit   50000
# 1   Rahul   75000
# 2   Priya   65000
# 3    Neha   90000
# 4  Vikram   45000

# %%
df[df["salary"]>60000]
# Out:
#     name  age    city  salary
# 1  Rahul   32    Pune   75000
# 2  Priya   28  Mumbai   65000
# 3   Neha   35   Delhi   90000

# %%
df[df["city"] == "Mumbai"]
# Out:
#     name  age    city  salary
# 0   Amit   25  Mumbai   50000
# 2  Priya   28  Mumbai   65000

# %%
df[ (df["salary"] > 60000) & (df["age"] > 25) ]
# Out:
#     name  age    city  salary
# 1  Rahul   32    Pune   75000
# 2  Priya   28  Mumbai   65000
# 3   Neha   35   Delhi   90000

# %%
df[ (df["city"] == "Mumbai") | (df["city"] == "Pune") ]
# Out:
#      name  age    city  salary
# 0    Amit   25  Mumbai   50000
# 1   Rahul   32    Pune   75000
# 2   Priya   28  Mumbai   65000
# 4  Vikram   24    Pune   45000

# %%
df[df["age"].between(25 ,32)]
# Out:
#     name  age    city  salary
# 0   Amit   25  Mumbai   50000
# 1  Rahul   32    Pune   75000
# 2  Priya   28  Mumbai   65000

# %%
df.loc[df["salary"] > 60000 , ["name" , "salary"]]
# Out:
#     name  salary
# 1  Rahul   75000
# 2  Priya   65000
# 3   Neha   90000

# %%
df.iloc[ : 3 , : 3]
# Out:
#     name  age    city
# 0   Amit   25  Mumbai
# 1  Rahul   32    Pune
# 2  Priya   28  Mumbai

# %%
df.loc[0, "age"]
# Out:
# np.int64(25)

# %%
df.iloc[0, 1]
# Out:
# np.int64(25)

# %%
df[ (df["city"].isin(["Mumbai" , "Pune"])) & (df["salary"] > 50000) ]
# Out:
#     name  age    city  salary
# 1  Rahul   32    Pune   75000
# 2  Priya   28  Mumbai   65000
