# %%
import pandas as pd

data = {
    "name": ["Amit", "Rahul", "Priya"],
    "age": [25, 30, 28],
    "salary": [50000, 70000, 65000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     name  age  salary
# 0   Amit   25   50000
# 1  Rahul   30   70000
# 2  Priya   28   65000

# %%
df
# Out:
#     name  age  salary
# 0   Amit   25   50000
# 1  Rahul   30   70000
# 2  Priya   28   65000

# %%
data = {
    "product": ["Laptop", "Mouse", "Keyboard", "Monitor"],
    "price": [60000, 1000, 2500, 15000],
    "stock": [10, 50, 30, 15]
}
gf = pd.DataFrame(data)

# %%
gf
# Out:
#     product  price  stock
# 0    Laptop  60000     10
# 1     Mouse   1000     50
# 2  Keyboard   2500     30
# 3   Monitor  15000     15

# %%
data = [
     ["Laptop", "Mouse", "Keyboard", "Monitor"],
     [60000, 1000, 2500, 15000],
     [10, 50, 30, 15]
    ]
df = pd.DataFrame(data , columns = ["Model" , "Price" , "stock" , "jato"])

# %%
df
# Out:
#     Model  Price     stock     jato
# 0  Laptop  Mouse  Keyboard  Monitor
# 1   60000   1000      2500    15000
# 2      10     50        30       15

# %%
data = [
    { "symbol" : "AAPL" , "price" : 220 } ,
{ "symbol" : "MSFT" , "price" : 510 },
 {"symbol" : "NVDA" , "price" : 180 },
 {"symbol" : "GOOGle" , "price" : 190 }
]
df = pd.DataFrame(data)

# %%
df
# Out:
#    symbol  price
# 0    AAPL    220
# 1    MSFT    510
# 2    NVDA    180
# 3  GOOGle    190

# %%
import numpy as np

# %%
data = np.array([
    [10, 20],
    [30, 40],
    [50, 60]
])

# %%
data
# Out:
# array([[10, 20],
#        [30, 40],
#        [50, 60]])

# %%
df = pd.DataFrame(
    data , columns = ["age" , "salary" ] )

# %%
df
# Out:
#    age  salary
# 0   10      20
# 1   30      40
# 2   50      60

# %%
data = { 
    "name" : ["Amit" , "Rahul" , "Priya" ],
    "age" : [21 ,22 ,23] 
}
df = pd.DataFrame(data , index = ["student_1" , "student_2" , "student_3"])

# %%
df
# Out:
#             name  age
# student_1   Amit   21
# student_2  Rahul   22
# student_3  Priya   23
